# %% [markdown]
# <a href="https://colab.research.google.com/github/ibrahimalabi7/Coursera_Capstone/blob/main/Capstone_Project_The_Battle_of_Neighborhoods_(Week_2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Capstone Project - The Battle of Neighborhoods (Week 2)
# ### Applied Data Science Capstone by IBM/Coursera
# #### By Omar Ibrahim Alabi

# %% [markdown]
# ## Table of contents
# * [Introduction: Business Problem](#introduction)
# * [Data](#data)
# * [Methodology](#methodology)
# * [Analysis](#analysis)
# * [Project Excecution](#project)
# * [Results and Discussion](#results)
# * [Conclusion](#conclusion)

# %% [markdown]
# # Introduction: Business Problem <a name="introduction"></a>

# %% [markdown]
# The problem:
#     Have you ever had the idea for meet new places and take your family to a new trip or unknow place and you had no idea about the places you can visit?

# %% [markdown]
# Weel, the problem indeed is many people have no idea of the closest places based on a specific type of location, and it will be very useful an application than can tell us what places we can visti and show us the distance and location. How cool will be that?

# %% [markdown]
# Background:
#     In my case, I have had that problem and I know many people is asking for it because is very natural that we my visit new places but we dont know the locations!!

# %% [markdown]
# ## Data <a name="data"></a>

# %% [markdown]
# Data required:
#     1. Location: Antiguo Cuscatlan, SV
#     2. Define search Criteria
#     3. Search for a specific venue category (This case, Mexican Food)
#     4. Data used: Only Foursquare locations

# %% [markdown]
# Purpose:
#     The goal of this project is provide to any person the facility and ability to search and visualize the closest locations for one specific place.
#     It can be a business idea and the target market can be anyone since we have the power of decide what kind of location we want

# %% [markdown]
# ## Methodology <a name="methodology"></a>

# %% [markdown]
# Purpose:
#     The goal of this project is provide to any person the facility and ability to search and visualize the closest locations for one specific place.
#     It can be a business idea and the target market can be anyone since we have the power of decide what kind of location we want

# %% [markdown]
# SCOPE:
#
# As we want to know the closest places, the need to follow the next steps:
#     1. Set our Foursquare API credentiales
#     2. Define the source location: In this case it will be Antiguo Cuscatlan, SV
#     3. Get the coordinates for the selected location
#     4. Define the search criteria: In this case it will be Mexican Food
#     5. Define the radio of search: In thus case it will be 2km
#     6. Use the Foursquare API to get the closest places
#     7. Show on Map the places

# %% [markdown]
# ## Analysis <a name="analysis"></a>

# %% [markdown]
# The anysis (EDA) or machine learning application will be not used since we only want to view on map the closest places from an specified location by using the Foursquare API

# %% [markdown]
# The exploration we may apply is checking the places by distance, I mean, what location es nearest to the source

# %% [markdown]
# ## Project Excecution <a name="project"></a>

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation


# !pip install geopy
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize


! pip install folium==0.5.0
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# ...
# Folium installed
# Libraries imported.

# %% [markdown]
# Let's define our credentials in order to connect with Foursquare API

# %%
CLIENT_ID = '4PPONDC2BG3KMZ4B5QQL4R4KFCSOK4XBXD1NT3ICS4EVQFBT' # your Foursquare ID
CLIENT_SECRET = 'M3BS305F13XE5Y1FA1K323YXSDUX2JF14IQCZ1OF1UBJYB50' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 100
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: 4PPONDC2BG3KMZ4B5QQL4R4KFCSOK4XBXD1NT3ICS4EVQFBT
# CLIENT_SECRET:M3BS305F13XE5Y1FA1K323YXSDUX2JF14IQCZ1OF1UBJYB50

# %% [markdown]
# Lets define the specific location (source)

# %%
address = 'Antiguo Cuscatlan, SV'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 13.670259999999999 -89.24631832742003

# %% [markdown]
# Now, we define the search criteria. In this case it will be Mexican Food

# %%
search_query = 'Mexican food'
radius = 2000
print(search_query + ' .... OK!')
# Out:
# Mexican food .... OK!

# %% [markdown]
# Define URL

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=4PPONDC2BG3KMZ4B5QQL4R4KFCSOK4XBXD1NT3ICS4EVQFBT&client_secret=M3BS305F13XE5Y1FA1K323YXSDUX2JF14IQCZ1OF1UBJYB50&ll=13.670259999999999,-89.24631832742003&v=20180604&query=Mexican food&radius=2000&limit=100'

# %% [markdown]
# Get the results

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5fb937f7e2d2433c217809f3'},
#  'response': {'venues': [{'id': '52053b4911d2c865cf665bf3',
#     'name': 'Mexican Grill',
#     'location': {'address': 'CC Las Cascadas',
#      'lat': 13.678159916583072,
#      'lng': -89.25041129129508,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.678159916583072,
#        'lng': -89.25041129129508}],
#      'distance': 984,
#      'cc': 'SV',
#      'country': 'El Salvador',
#      'formattedAddress': ['CC Las Cascadas', 'El Salvador']},
#     'categories': [{'id': '4bf58dd8d48988d1c1941735',
#       'name': 'Mexican Restaurant',
#       'pluralName': 'Mexican Restaurants',
#       'shortName': 'Mexican',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1605974007',
#     'hasPerk': False},
#    {'id': '50b8f870e4b0e9ecea5913a0',
#     'name': 'Mexican Grill Las Cascadas',
# ...

# %% [markdown]
# Define the Dataframe with the results

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
# <ipython-input-9-5acf500bf9ad>:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   dataframe = json_normalize(venues)
#                          id                          name  \
# 0  52053b4911d2c865cf665bf3                 Mexican Grill
# 1  50b8f870e4b0e9ecea5913a0    Mexican Grill Las Cascadas
# 2  573be280cd10da7e81d81ae1  Mexican Taco Truck- La Frida
# 3  4c361e1f2c8020a15fc68600                     Pizza Hut
# 4  4ea468b3b8f7e4911f740faa       Miin House Chinese Food
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1c1941735', 'name': 'M...  v-1605974007    False
# 1  [{'id': '4bf58dd8d48988d1c1941735', 'name': 'M...  v-1605974007    False
# 2  [{'id': '4bf58dd8d48988d1cb941735', 'name': 'F...  v-1605974007    False
# 3  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...  v-1605974007    False
# ...

# %% [markdown]
# Dataframe filtering

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                  name            categories  \
# 0                       Mexican Grill    Mexican Restaurant
# 1          Mexican Grill Las Cascadas    Mexican Restaurant
# 2        Mexican Taco Truck- La Frida            Food Truck
# 3                           Pizza Hut           Pizza Place
# 4             Miin House Chinese Food  Cantonese Restaurant
# 5                           Star Food      Asian Restaurant
# 6                        Healthy Food            Restaurant
# 7          El Greco Greek Casual Food      Greek Restaurant
# 8                     food priceSmart   American Restaurant
# 9             La Neveria @ Food Court        Ice Cream Shop
# 10            Food Court - Multiplaza            Food Court
# 11                       Vicky's Food                  None
# 12           Food court ,UCA peatonal                  Food
# 13             Pizza Hut @ Food Court           Pizza Place
# 14                         Crazy Food  Fast Food Restaurant
# ...

# %% [markdown]
# Getting the locations name

# %%
dataframe_filtered.name
# Out:
# 0                         Mexican Grill
# 1            Mexican Grill Las Cascadas
# 2          Mexican Taco Truck- La Frida
# 3                             Pizza Hut
# 4               Miin House Chinese Food
# 5                             Star Food
# 6                          Healthy Food
# 7            El Greco Greek Casual Food
# 8                       food priceSmart
# 9               La Neveria @ Food Court
# 10              Food Court - Multiplaza
# 11                         Vicky's Food
# 12             Food court ,UCA peatonal
# 13               Pizza Hut @ Food Court
# 14                           Crazy Food
# 15                  Zona Pea Food Court
# 16              El Arriero @ Food Court
# 17                 Quiznos @ Food Court
# 18    China Wok, Food Court Multiplaza.
# 19         Subway Food Court Multiplaza
# 20         Food Star - Comida Taiwanesa
# 21             Papa John's @ Food Court
# 22                         Seoul Garden
# ...

# %%
dataframe_filtered.shape
# Out:
# (37, 15)

# %% [markdown]
# Show on MAP

# %%
antiguo_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
folium.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Antiguo Cuscatlan',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(antiguo_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(antiguo_map)

# display map
antiguo_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Checking the locations by distance (Nearest locations), Top5

# %%
top5 = dataframe_filtered.sort_values(by='distance', ascending=True).head()
top5
# Out:
#                        name            categories            address  \
# 5                 Star Food      Asian Restaurant                NaN
# 4   Miin House Chinese Food  Cantonese Restaurant  Antiguo Cuscatlán
# 8           food priceSmart   American Restaurant                NaN
# 6              Healthy Food            Restaurant                NaN
# 22             Seoul Garden     Korean Restaurant                NaN
#
#           lat        lng                                     labeledLatLngs  \
# 5   13.673131 -89.240306  [{'label': 'display', 'lat': 13.67313126497153...
# 4   13.671465 -89.238864  [{'label': 'display', 'lat': 13.67146496570492...
# 8   13.663311 -89.248824  [{'label': 'display', 'lat': 13.66331055148003...
# 6   13.677736 -89.244865  [{'label': 'display', 'lat': 13.67773595075896...
# 22  13.678588 -89.244168  [{'label': 'display', 'lat': 13.67858793845103...
#
#     distance  cc      country                  formattedAddress crossStreet  \
# ...

# %% [markdown]
# ## Results and Discussion <a name="results"></a>

# %% [markdown]
# My exploration shows 37 record of places close to Antiguo Cuscatlan in a radio of 2km.
# The results are very intersting since we can identify places we have never heard before and thats the beauty of this!
#
# The locations are in the central zone of the City since we may have no problem to get there

# %% [markdown]
# ## Conclusion <a name="conclusion"></a>

# %% [markdown]
# As I mention before, the purpose of this project is to provide to any person the facility and ability to search and visualize the closest locations for one specific place, so we can identify the nearest location from the source.
#
# **In order to take a decission, we can use the top5 of nearest location to choose the location we want to visit.**
